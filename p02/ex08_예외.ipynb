# %%
# https://codelaba.netlify.app
# 주피터 노트북
# 실행: shift+enter, ctrl+enter

try:
	print(1 / 0)
except ZeroDivisionError:
	print('Division by zero error')
finally:
	print('This will always be printed')
# Out:
# Division by zero error
# This will always be printed

# %%
try:
    print(1 / 0)
except ZeroDivisionError:
    print('0으로 나누면 안돼요!')
finally:
    print('완료!')

# %%
# 예약어: try, except, finally, ...
# 예외(exception) 처리: 에러 예방
""" 
    try:
        에러 발생 가능 문장
    except 에러종류:
        처리 문장
    finally:
        마지막 실행 문장
"""
# Out:
# ' \n    try:\n        에러 발생 가능 문장\n    except 에러종류:\n        처리 문장\n    finally:\n        마지막 실행 문장\n'

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero
