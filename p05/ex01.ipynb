# %%
# 패키지(package)
# -> 모듈 그룹
# -> numpy, pandas, matplotlib
# 모듈(module) -> *.py -> usecsv.py
# pip 
# -> PyPI에 있는 패키지를 설치하는도구(command tool)
# pypi(Python Package Index)
# -> 파이썬 패키지들을 저장해두는온라인 저장소(사이트)
# https://pypi.org/

# %%
# 설치
# 터미널: pip install numpy
# 셀: !pip install numpy pandas

# 삭제
# pip uninstall requests

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.4.6

# %%
# 설치 목록 확인
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.2
# beautifulsoup4          4.15.0
# certifi                 2026.7.22
# charset-normalizer      3.5.1
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.21
# executing               2.2.1
# fonttools               4.64.0
# idna                    3.19
# ipykernel               7.3.0
# ipython                 9.17.1
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# jupyter_client          8.10.0
# jupyter_core            5.9.1
# kiwisolver              1.5.1
# matplotlib              3.11.1
# matplotlib-inline       0.2.2
# nest-asyncio2           1.7.2
# numpy                   2.4.6
# packaging               26.3
# pandas                  3.0.5
# parso                   0.8.7
# pillow                  12.3.0
# pip                     26.2.1
# platformdirs            4.11.6
# prompt_toolkit          3.0.53
# psutil                  7.2.2
# pure_eval               0.2.3
# Pygments                2.21.0
# pyparsing               3.3.2
# python-dateutil         2.9.0.post0
# pyzmq                   27.2.0
# requests                2.34.2
# setuptools              84.0.0
# six                     1.17.0
# soupsieve               2.9.2
# stack-data              0.6.3
# tornado                 6.5.8
# traitlets               5.16.1
# typing_extensions       4.16.0
# tzdata                  2026.3
# urllib3                 2.7.0
# wcwidth                 0.8.3
# wheel                   0.48.0

# %%
# pip 버전 확인
# !pip --version
# Out:
# pip 26.2.1 from E:\wi\git\py0811\.venv\Lib\site-packages\pip (python 3.11)

# %%
# pip 업그레이드
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in E:\wi\git\py0811\.venv\Lib\site-packages (26.2.1)
